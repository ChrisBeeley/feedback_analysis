# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import NMF, LatentDirichletAllocation
import numpy as np

no_topics = 10
no_top_words = 6 
no_top_documents = 5

# %%
feedback = pd.read_csv("../for_gensim.csv", encoding = "latin-1", na_values=[])

# convert the 2nd column values to a list
documents = feedback["Improve"].tolist()

# feedback.head(n = 5)

# %%
def display_topics(H, W, feature_names, documents, no_top_words, no_top_documents):
    for topic_idx, topic in enumerate(H):
        print("Topic %d:" % (topic_idx))
        print(" ".join([feature_names[i]
                        for i in topic.argsort()[:-no_top_words - 1:-1]]))
        top_doc_indices = np.argsort( W[:,topic_idx] )[::-1][0:no_top_documents]
        for doc_index in top_doc_indices:
            print(documents[doc_index])

# NMF is able to use tf-idf
tfidf_vectorizer = TfidfVectorizer(max_df=0.95, min_df=2, stop_words='english')
tfidf = tfidf_vectorizer.fit_transform(documents)
tfidf_feature_names = tfidf_vectorizer.get_feature_names()

# Run NMF
nmf_model = NMF(n_components=no_topics, random_state=1, alpha=.1, l1_ratio=.5, init='nndsvd').fit(tfidf)
nmf_W = nmf_model.transform(tfidf)
nmf_H = nmf_model.components_

print("NMF Topics")
display_topics(nmf_H, nmf_W, tfidf_feature_names, documents, no_top_words, no_top_documents)
print("--------------")
# Out:
# NMF Topics
# Topic 0:
# people help dont need better feel
# people that i feel need to go there for help
# for the doctors to do more for the people who need help
# sort out hospital appointments for people who need them help people who are struggling with there pain meds i have asked may different thing due to my pain levels and meds and have had no help at all i dont get listened to when i talk about my pain levels and nothing ever changes i have sent may healthcare apps in and i have had no response sometime different people are giving the impression they dont care about what im asking for they just do or change whatever they think will help you without talking about it with me first they just dont seem to care about what your problems are and do as little as they can to help
# i thought i would need a lot longer to feel better i dont think i need bereavement help now either
# help people like me with drink problems we still need this help
# Topic 1:
# staff patients ward activities busy listen
# have more staff on there is not enough staff for all the patients on the ward
# that communication is much improved between staff and staff and staff to carer
# more staff to have more 1 to 1 time with
# staff work very here and always there for us they could do with more staff they are always so busy
# more staff to do more on and off the ward
# Topic 2:
# long wait months treatment seen weeks
# not to have to wait so long 4 months was too long
# to not have to wait too long to be seen
# to long a wait for start of treatment six months is a very long time
# how long you have to wait to get an appointment
# less time to next appointment the wait is too long
# Topic 3:
# time spend nurses talk length appointments
# to give me more time to get to my appointment on time i am all late on time
# more staff to have more 1 to 1 time with
# more one to one time would be better for me
# give more time for visits they are always in out and dont always have time to get to know you
# cant do it but less people at any one time
# Topic 4:
# health mental visitor visitors services issues
# for me to have more contact with mental health which i am now
# he has been let down by the mental health system
# mental health other than a nurse who just did an assessment not seen my mental health worker
# yes the stigma associated with mental health and more funds spent on mental health no a visit to the hospital mental health is not good tell our government to get their finger out and recognise mental health issues
# i have been let down i would not wish this treatment on anyone yet alone someone with mental health problems please do something to change the state of our mental health care
# Topic 5:
# sessions longer course session group liked
# would like to have the sessions last longer ie more sessions
# more and longer sessions as they used to be weekly sessions would be better
# i would have like to have more therapy sessions however this is no longer aproblem
# would have liked sessions for a longer amount of time
# needs to be more sessions and long time in each sessions
# Topic 6:
# appointment make appointments able cancelled phone
# it can sometimes take a while to get an appointment to see someone
# making an appointment was much better being able to make next appointment at treatment
# sometimes you have to wait a while for an appointment
# more appointment slots have to wait weeksmonths for first appointment
# better appointment service able to make next appointment in advance
# Topic 7:
# like visit come feel nurse nurses
# i feel i would like morep hysiotherapy on my own
# i would like to come later i dont like getting up
# food i would like to request things what i like
# i would like to see the same nurse each visit
# would like to see the same nurse at each visit
# Topic 8:
# waiting times list room shorter long
# less of a waiting list when waiting to see someone
# shorter waiting times only waiting time for appointments is long
# not so long waiting times more for babies in waiting room
# there are very long waiting times for any support i have been waiting well over a year now
# shorter waiting times waiting too long in waiting room not getting appointment slips on time
# Topic 9:
# service good excellent users access improve
# there is nothing i would improve about the service as a whole the service is excellent
# i couldnt think of anything the service was excellent the only thing would be that we couldnt have the service for longer
# excellent service it would be nice to receive service 7 days
# good service better than other jails i have been in more time to see you
# provide the service for longer give at least 2 weeks notice of termination of the service
# --------------
